# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
#df=pd.read_csv('results.txt', sep=':')
#passes = [(i+1) for i in df.index]
#df.insert(0, 'image', passes)

# %%
titanic = sns.load_dataset("titanic")
print type(titanic)
titanic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
df=pd.read_csv('results.txt', sep=':')
passes = [(i+1) for i in df.index]
df.insert(0, 'image', passes)

# %%
df.head()
# Out:
#    image                                               Test  \
# 0      1  /home/fgonda/icon/data/reference/images/test/t...
# 1      2  /home/fgonda/icon/data/reference/images/test/a...
# 2      3  /home/fgonda/icon/data/reference/images/test/a...
# 3      4  /home/fgonda/icon/data/reference/images/test/t...
# 4      5  /home/fgonda/icon/data/reference/images/test/t...
#
#                                           Validation  \
# 0  /home/fgonda/icon/data/reference/labels/test/t...
# 1  /home/fgonda/icon/data/reference/labels/test/a...
# 2  /home/fgonda/icon/data/reference/labels/test/a...
# 3  /home/fgonda/icon/data/reference/labels/test/t...
# 4  /home/fgonda/icon/data/reference/labels/test/t...
#
#                                             Membrane  PixelError  \
# 0  /home/fgonda/icon/data/reference/labels/membra...    0.374572
# 1  /home/fgonda/icon/data/reference/labels/membra...    0.355991
# 2  /home/fgonda/icon/data/reference/labels/membra...    0.402710
# 3  /home/fgonda/icon/data/reference/labels/membra...    0.373307
# 4  /home/fgonda/icon/data/reference/labels/membra...    0.372207
#
#    VariationInfo
# 0       1.250404
# 1       1.727361
# 2       2.355627
# 3       1.162565
# 4       0.858294

# %%
#df.index

# %%
sns.pointplot(x="image", y="VariationInfo", data=df,
              markers=["o"], linestyles=["-"]);

# %%
sns.pointplot(x="image", y="PixelError", data=df,
              markers=["o"], linestyles=["-"]);
